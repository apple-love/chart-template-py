# %% [markdown]
# # 使用Python进行数据可视化

# %% [markdown]
# 梁文昊  2024/5/15

# %% [markdown]
# ## 1. matplotlib

# %%
import matplotlib.pyplot as plt 
import numpy as np  
plt.figure(facecolor='white',figsize=(6,4),dpi=100) 
plt.rc('font', family="Times New Roman")

# %% [markdown]
# ### 折线图

# %%
x=np.array([1,3,5])  
y1=x  
y5=x+10
y2=x * 10  
y3=x * 20  
y4=x * 30
plt.plot(x,y1,label='A')  
plt.plot(x,y5,label='A2', linewidth=5,color='red')
plt.plot(x,y2,label='B', marker='o')  
plt.plot(x,y3,label='C', linestyle='--')  
plt.plot(x,y4,label='D', marker='^', linestyle='--', linewidth=5, markersize='20')   
plt.xlabel('X label', fontsize=17)
plt.ylabel('Y label', fontsize=17)
plt.title("Line Chart", fontsize=19)

plt.legend(fontsize=13)
# plt.savefig('Fig1.pdf')

# %%
plt.figure(facecolor='white',figsize=(9,6)) 

plt.subplot(221)  
plt.plot(x,y1,label='A',color='r')  
plt.xticks(fontsize=15)  
plt.legend(loc=1)#显示图例   
plt.grid(ls="--", alpha=0.5)
plt.xlabel('X label', fontsize=17)
plt.ylabel('Y label', fontsize=17)

plt.subplot(222)  
plt.plot(x,y2,label='B',color='y')  
plt.xticks(fontsize=15)  
plt.legend(loc=2)#显示图例  
plt.grid(ls="--", alpha=1)
plt.xlabel('X label', fontsize=17)
plt.ylabel('Y label', fontsize=17)

plt.subplot(223)  
plt.plot(x,y3,label='C',color='b')  
plt.xticks(fontsize=15)  
plt.legend(loc=3)#显示图例 
plt.xlabel('X label', fontsize=17)
plt.ylabel('Y label', fontsize=17)

plt.subplot(224)  
plt.plot(x,y4,label='D',color='g')  
plt.xticks(fontsize=15)  
plt.legend(loc=4)#显示图例   
plt.xlabel('X label', fontsize=17)
plt.ylabel('Y label', fontsize=17)
plt.tight_layout()#密集显示

# %% [markdown]
# ### 柱状图

# %%
x = range(5)
data = [5, 20, 15,25,10]
plt.grid(ls="--", alpha=0.5)
plt.bar(x, data, color=['r', 'g', 'b'])
plt.xlabel('X label', fontsize=17)
plt.ylabel('Y label', fontsize=17)
plt.title("Bar Chart", fontsize=19)
# plt.legend(fontsize=13)
# plt.savefig('Fig1.pdf')
# Out:
# Text(0.5, 1.0, 'Bar Chart')

# %%
plt.figure(facecolor='white',figsize=(8,3),dpi=200) 
plt.subplot(121)  
plt.bar(x, data, color=['r', 'g', 'b']) 
plt.xticks(fontsize=15)  
# plt.legend()#显示图例   
plt.grid(ls="--", alpha=0.5)
plt.xlabel('X label', fontsize=17)
plt.ylabel('Y label', fontsize=17)

plt.subplot(122)  
plt.bar(x, data, color=['r', 'g', 'b']) 
plt.xticks(fontsize=15)  
# plt.legend()#显示图例  
plt.grid(ls="--", alpha=1)
plt.xlabel('X label', fontsize=17)
plt.ylabel('Y label', fontsize=17)

plt.tight_layout()#密集显示

# %%
plt.figure(figsize=(8, 5), dpi=200)
# 构造x轴刻度标签、数据
# labels = ['64×64', '128×128', '192×192', '256×256']
labels = ['0', '1', '2', '3', '4', '5']
im2col1 = [ 1.E+13,7.E+12,2.E+13,6.E+12,6.E+12,6.E+12]
scatter1 = [2.E+12,1.E+12,6.E+12,2.E+12,2.E+12,2.E+12]
new = [2.E+08,9.E+07,3.E+07,1.E+11,1.E+10,1.E+10]
y_ticks = ([1.E+04,1.E+06,1.E+08,1.E+10,1.E+12,1.E+14])

x = np.arange(len(labels))  # x轴刻度标签位置
# plt.bar(x, first, width, color=['#808080', '#FB6F6F', '#F4A666', '#4FBDFF', '#AF550C'])
width = 0.18  # 柱子的宽度
r1 = np.arange(len(labels))
r2 = [x + width+0.07-0.25 for x in r1] 
r3 = [x + width+0.07 for x in r2] 
# 计算每个柱子在x轴上的位置，保证x轴刻度标签居中
# x - width/2，x + width/2即每组数据在x轴上的位置
old = plt.bar(r1-0.25, im2col1, width, label='old')
opt = plt.bar(r2, scatter1, width, label='opt')
new = plt.bar(r3, new, width, label='new')
plt.xlabel('Matrix Element Type', fontsize=17)
plt.ylabel('Executed Instructions', fontsize=17)
plt.yscale('log')
plt.xticks(x, labels=labels)
plt.yticks(y_ticks)

# 添加网格线
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=1, color='grey', alpha=0.7)
plt.legend(ncol=3, fontsize=10)

# plt.savefig('Figs/Executed_Instructions.pdf')  # 保存为PDF
plt.show()

# %%
#库导入
from matplotlib import pyplot as plt
import numpy as np

#参数设置
plt.rcParams['font.sans-serif'] = ['Times New Roman']
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.dpi'] = 100
plt.rcParams['figure.figsize'] = (6,3)

#国家和奖牌数据导入
countries = ['A', 'B', 'C', 'D', 'E']
gold_medal = [16, 12, 9, 8, 8]
silver_medal = [8, 10, 4, 10, 5]
bronze_medal = [13, 5, 2, 7, 5]

#将横坐标国家转换为数值
x = np.arange(len(countries))
width = 0.2

#计算每一块的起始坐标
gold_x = x
silver_x = x + width
bronze_x = x + 2 * width

#绘图
plt.bar(gold_x,gold_medal,width=width,color="gold",label="gold")
plt.bar(silver_x,silver_medal,width=width,color="silver",label="silver")
plt.bar(bronze_x,bronze_medal,width=width, color="saddlebrown",label="saddlebrown")

#将横坐标数值转换为国家
plt.xticks(x + width,labels=countries)

#显示柱状图的高度文本
for i in range(len(countries)):
    plt.text(gold_x[i],gold_medal[i], gold_medal[i],va="bottom",ha="center",fontsize=8)
    plt.text(silver_x[i],silver_medal[i], gold_medal[i],va="bottom",ha="center",fontsize=8)
    plt.text(bronze_x[i],bronze_medal[i], gold_medal[i],va="bottom",ha="center",fontsize=8)  

#显示图例
plt.legend(loc="upper right")

# %%
#库导入
from matplotlib import pyplot as plt
import numpy as np

#参数设置
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = (5,3)

#国家和奖牌数据输入、柱状图宽度设置
countries = ['A', 'B', 'C', 'D', 'E']
gold_medal = np.array([16, 12, 9, 8, 8])
silver_medal = np.array([8, 10, 4, 10, 5])
bronze_medal = np.array([13, 5, 2, 7, 5])
width = 0.3

#绘图
plt.bar(countries, gold_medal, color='gold', label='gold',bottom=silver_medal + bronze_medal,width=width)
plt.bar(countries, silver_medal, color='silver', label='silver', bottom=bronze_medal,width=width)
plt.bar(countries, bronze_medal, color='saddlebrown', label='saddlebrown', width=width)

#设置y轴标签，图例和文本值
y_ticks = np.linspace(0,40,11)
plt.ylabel('number')
plt.yticks(y_ticks)
plt.legend(loc='upper right', fontsize=8)
for i in range(len(countries)):
    max_y = bronze_medal[i]+silver_medal[i]+gold_medal[i]
    plt.text(countries[i],max_y,max_y,ha='center',va='bottom')

# %% [markdown]
# ### Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot(index='month', columns='year', values='passengers')

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <Axes: xlabel='year', ylabel='month'>
